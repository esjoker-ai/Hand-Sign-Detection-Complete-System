# %%
# !pip install ultralytics
import os
import yaml



# 2. Create a new correct YAML
new_yaml_content = {
    'train': '/kaggle/input/sign-language/train/images',
    'val': '/kaggle/input/sign-language/test/images',
    'nc': 6,  # Number of classes (update if needed)
    'names': ['Hello', 'IloveYou', 'No', 'Please', 'Thanks', 'Yes']
}

# Save new data.yaml in working directory
new_yaml_path = '/kaggle/working/data.yaml'

with open(new_yaml_path, 'w') as f:
    yaml.dump(new_yaml_content, f)

print(f"✅ New data.yaml created at {new_yaml_path}")
# Out:
# ...
# ✅ New data.yaml created at /kaggle/working/data.yaml

# %%
# !yolo task=detect mode=train data="data.yaml" model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
